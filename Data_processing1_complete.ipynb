# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
import os
from glob import glob

import pandas as pd
import numpy as np

# %%
data_dir = '/gdrive/MyDrive/0. 인공지능 학습/아이펠 대전 3기/5. 해커톤/1차 해커톤/data'
save_data_dir = '/gdrive/MyDrive/0. 인공지능 학습/아이펠 대전 3기/5. 해커톤/1차 해커톤/processed_data'

# 아마존
amazon_credits_path = os.path.join(data_dir, "아마존", "credits.csv")
amazon_titles_path = os.path.join(data_dir, "아마존", "titles.csv")
# 넷플릭스
netflix_credits_path = os.path.join(data_dir, "넷플릭스", "credits.csv")
netflix_titles_path = os.path.join(data_dir, "넷플릭스", "titles.csv")
# 디즈니
disney_credits_path = os.path.join(data_dir, "디즈니", "credits.csv")
disney_titles_path = os.path.join(data_dir, "디즈니", "titles.csv")
# 파라마운트
paramount_credits_path = os.path.join(data_dir, "파라마운트", "credits.csv")
paramount_titles_path = os.path.join(data_dir, "파라마운트", "titles.csv")

# %%
credits_paths = [amazon_credits_path, netflix_credits_path, disney_credits_path, paramount_credits_path]
credits_save_file_names = ["amazon_credits.csv", "netflix_credits.csv", "disney_credits.csv", "paramount_credits.csv"]

titles_paths = [amazon_titles_path, netflix_titles_path, disney_titles_path, paramount_titles_path]
titles_save_file_names = ["amazon_titles.csv", "netflix_titles.csv", "disney_titles.csv", "paramount_titles.csv"]

# %%
amazon_credits = pd.read_csv(credits_paths[0])
amazon_credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124235 entries, 0 to 124234
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   person_id  124235 non-null  int64
#  1   id         124235 non-null  object
#  2   name       124235 non-null  object
#  3   character  107948 non-null  object
#  4   role       124235 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 4.7+ MB

# %%
amazon_titles = pd.read_csv(titles_paths[0])
amazon_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
#  2   type                  9871 non-null   object
#  3   description           9752 non-null   object
#  4   release_year          9871 non-null   int64
#  5   age_certification     3384 non-null   object
#  6   runtime               9871 non-null   int64
#  7   genres                9871 non-null   object
#  8   production_countries  9871 non-null   object
#  9   seasons               1357 non-null   float64
#  10  imdb_id               9204 non-null   object
#  11  imdb_score            8850 non-null   float64
#  12  imdb_votes            8840 non-null   float64
#  13  tmdb_popularity       9324 non-null   float64
#  14  tmdb_score            7789 non-null   float64
# ...

# %%
amazon_titles.head()
# Out:
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
#                                               genres production_countries  \
# ...

# %%
amazon_credits.head()
# Out:
#    person_id       id           name      character   role
# 0      59401  ts20945     Joe Besser            Joe  ACTOR
# 1      31460  ts20945     Moe Howard            Moe  ACTOR
# 2      31461  ts20945     Larry Fine          Larry  ACTOR
# 3      21174  tm19248  Buster Keaton    Johnny Gray  ACTOR
# 4      28713  tm19248    Marion Mack  Annabelle Lee  ACTOR

# %%
amazon_titles.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   9871.000000  9871.000000  1357.000000  8850.000000  8.840000e+03
# mean    2001.327221    85.973052     2.791452     5.976395  8.533614e+03
# std       25.810071    33.512466     4.148958     1.343842  4.592015e+04
# min     1912.000000     1.000000     1.000000     1.100000  5.000000e+00
# 25%     1995.500000    65.000000     1.000000     5.100000  1.170000e+02
# 50%     2014.000000    89.000000     1.000000     6.100000  4.625000e+02
# 75%     2018.000000   102.000000     3.000000     6.900000  2.236250e+03
# max     2022.000000   549.000000    51.000000     9.900000  1.133692e+06
#
#        tmdb_popularity   tmdb_score
# count      9324.000000  7789.000000
# mean          6.910204     5.984247
# std          30.004098     1.517986
# min           0.000011     0.800000
# 25%           1.232000     5.100000
# 50%           2.536000     6.000000
# 75%           5.634000     6.900000
# ...

# %%
amazon_credits.describe()
# Out:
#           person_id
# count  1.242350e+05
# mean   4.064737e+05
# std    5.616296e+05
# min    1.000000e+00
# 25%    3.899200e+04
# 50%    1.339490e+05
# 75%    5.712560e+05
# max    2.371153e+06

# %% [markdown]
# # credits 파일
# - 중복 제거

# %%
def credits_process(credits_paths, save_data_dir, file_names):
    for i, path in enumerate(credits_paths):
        credits = pd.read_csv(path)
        # 중복 제거
        credits.drop_duplicates()

        # csv 저장
        save_data_path = os.path.join(save_data_dir, file_names[i])
        print("저장 경로 :", save_data_path)
        credits.to_csv(save_data_path, index=False)

# %%
credits_process(credits_paths, save_data_dir, credits_save_file_names)
# Out:
# 저장 경로 : /gdrive/MyDrive/0. 인공지능 학습/아이펠 대전 3기/5. 해커톤/1차 해커톤/processed_data/amazon_credits.csv
# 저장 경로 : /gdrive/MyDrive/0. 인공지능 학습/아이펠 대전 3기/5. 해커톤/1차 해커톤/processed_data/netflix_credits.csv
# 저장 경로 : /gdrive/MyDrive/0. 인공지능 학습/아이펠 대전 3기/5. 해커톤/1차 해커톤/processed_data/disney_credits.csv
# 저장 경로 : /gdrive/MyDrive/0. 인공지능 학습/아이펠 대전 3기/5. 해커톤/1차 해커톤/processed_data/paramount_credits.csv

# %% [markdown]
# # titles 파일
# - 중복 제거
# - IMDB ID column 제거

# %%
def titles_process(titles_paths, save_data_dir, file_names):
    for i, path in enumerate(titles_paths):
        titles = pd.read_csv(path)
        # 중복 제거
        titles.drop_duplicates()

        # imdb_id column 제거
        del titles["imdb_id"]

        # csv 저장
        save_data_path = os.path.join(save_data_dir, file_names[i])
        print("저장 경로 :", save_data_path)
        titles.to_csv(save_data_path, index=False)

# %%
titles_process(titles_paths, save_data_dir, titles_save_file_names)
# Out:
# 저장 경로 : /gdrive/MyDrive/0. 인공지능 학습/아이펠 대전 3기/5. 해커톤/1차 해커톤/processed_data/amazon_titles.csv
# 저장 경로 : /gdrive/MyDrive/0. 인공지능 학습/아이펠 대전 3기/5. 해커톤/1차 해커톤/processed_data/netflix_titles.csv
# 저장 경로 : /gdrive/MyDrive/0. 인공지능 학습/아이펠 대전 3기/5. 해커톤/1차 해커톤/processed_data/disney_titles.csv
# 저장 경로 : /gdrive/MyDrive/0. 인공지능 학습/아이펠 대전 3기/5. 해커톤/1차 해커톤/processed_data/paramount_titles.csv

# %%
path = os.path.join(save_data_dir, titles_save_file_names[0])
titles = pd.read_csv(path)

# %%
titles
# Out:
#              id                            title   type  \
# 0       ts20945                The Three Stooges   SHOW
# 1       tm19248                      The General  MOVIE
# 2       tm82253      The Best Years of Our Lives  MOVIE
# 3       tm83884                  His Girl Friday  MOVIE
# 4       tm56584                In a Lonely Place  MOVIE
# ...         ...                              ...    ...
# 9866   tm510327                     Lily Is Here  MOVIE
# 9867  tm1079144  Jay Nog: Something from Nothing  MOVIE
# 9868   tm847725                          Chasing  MOVIE
# 9869  tm1054116                         Baikunth  MOVIE
# 9870   ts275838                 Waking Up Eighty   SHOW
#
#                                             description  release_year  \
# 0     The Three Stooges were an American vaudeville ...          1934
# 1     During America’s Civil War, Union spies steal ...          1926
# 2     It's the hope that sustains the spirit of ever...          1946
# ...
